# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/inputevents.csv'

# Load the CSV into a DataFrame
input = pd.read_csv(file_path)

# Display the first few rows to confirm it loaded correctly
print(input.head())
# Out:
#    subject_id   stay_id            starttime              endtime  itemid  \
# 0    10002428  34807493  2156-05-01 08:00:00  2156-05-01 08:01:00  225799
# 1    10002428  34807493  2156-05-01 08:00:00  2156-05-01 08:01:00  225975
# 2    10002428  34807493  2156-05-01 08:00:00  2156-05-01 08:01:00  226453
# 3    10002428  34807493  2156-05-01 10:00:00  2156-05-01 10:01:00  220949
# 4    10002428  34807493  2156-05-01 10:00:00  2156-05-01 10:01:00  225884
#
#    amount amountuom  totalamount totalamountuom  rate rateuom
# 0    30.0        mL         30.0             mL   NaN     NaN
# 1     1.0      dose          NaN            NaN   NaN     NaN
# 2    50.0        mL         50.0             mL   NaN     NaN
# 3   100.0        mL        100.0             mL   NaN     NaN
# 4     1.0      dose        100.0             mL   NaN     NaN

# %%
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3174060 entries, 0 to 3174059
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   subject_id      int64
#  1   stay_id         int64
#  2   starttime       object
#  3   endtime         object
#  4   itemid          int64
#  5   amount          float64
#  6   amountuom       object
#  7   totalamount     float64
#  8   totalamountuom  object
#  9   rate            float64
#  10  rateuom         object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 266.4+ MB

# %%
# Convert starttime and endttime to an datetime
input['starttime'] = input['starttime'].astype('datetime64[ns]')
input['endtime'] = input['endtime'].astype('datetime64[ns]')
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3174060 entries, 0 to 3174059
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   subject_id      int64
#  1   stay_id         int64
#  2   starttime       datetime64[ns]
#  3   endtime         datetime64[ns]
#  4   itemid          int64
#  5   amount          float64
#  6   amountuom       object
#  7   totalamount     float64
#  8   totalamountuom  object
#  9   rate            float64
#  10  rateuom         object
# dtypes: datetime64[ns](2), float64(3), int64(3), object(3)
# memory usage: 266.4+ MB

# %%
# Count the number of unique subject_ids / patients in this dataframe
print(f'Number of patients: {input["subject_id"].nunique()}')
# Out:
# Number of patients: 5832

# %%
# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column into the ventilation dataframe using itemid
input = input.merge(
    d_items[['itemid', 'label']],  # Only keep necessary columns
    on='itemid',
    how='left'  # Keep all rows from ventilation
)

# %%
input.head(50)
# Out:
#     subject_id   stay_id           starttime             endtime  itemid  \
# 0     10002428  34807493 2156-05-01 08:00:00 2156-05-01 08:01:00  225799
# 1     10002428  34807493 2156-05-01 08:00:00 2156-05-01 08:01:00  225975
# 2     10002428  34807493 2156-05-01 08:00:00 2156-05-01 08:01:00  226453
# 3     10002428  34807493 2156-05-01 10:00:00 2156-05-01 10:01:00  220949
# 4     10002428  34807493 2156-05-01 10:00:00 2156-05-01 10:01:00  225884
# 5     10002428  34807493 2156-05-01 11:15:00 2156-05-01 11:16:00  225158
# 6     10002428  34807493 2156-05-01 12:00:00 2156-05-01 12:01:00  225798
# 7     10002428  34807493 2156-05-01 12:00:00 2156-05-01 12:01:00  225799
# 8     10002428  34807493 2156-05-01 12:00:00 2156-05-01 12:01:00  226453
# 9     10002428  34807493 2156-05-01 13:12:00 2156-05-01 13:13:00  220949
# 10    10002428  34807493 2156-05-01 13:12:00 2156-05-01 13:13:00  225851
# 11    10002428  34807493 2156-05-01 13:45:00 2156-05-01 13:46:00  220949
# 12    10002428  34807493 2156-05-01 13:45:00 2156-05-01 13:46:00  225798
# 13    10002428  34807493 2156-05-01 14:00:00 2156-05-01 14:01:00  225799
# 14    10002428  34807493 2156-05-01 14:00:00 2156-05-01 14:01:00  226453
# 3   100.000000        mL        100.0             mL         NaN         NaN
# 4     1.000000      dose        100.0             mL         NaN         NaN
# 5   500.000000        mL        500.0             mL         NaN         NaN
# 6     1.000000      dose          NaN            NaN         NaN         NaN
# 7    10.000000        mL         10.0             mL         NaN         NaN
# 8    30.000000        mL         30.0             mL         NaN         NaN
# 9    50.000000        mL         50.0             mL         NaN         NaN
# 10    1.000000      dose         50.0             mL         NaN         NaN
# 11  200.000000        mL        200.0             mL         NaN         NaN
# 12    1.000000      dose        200.0             mL         NaN         NaN
# 13   30.000000        mL         30.0             mL         NaN         NaN
# 14   30.000000        mL         30.0             mL         NaN         NaN
# 15    1.000000      dose          NaN            NaN         NaN         NaN
# 16  500.000000        mL        500.0             mL         NaN         NaN
# 17    1.000000      dose          NaN            NaN         NaN         NaN
# 18   10.000000        mL         10.0             mL         NaN         NaN
# 19   30.000000        mL         30.0             mL         NaN         NaN
# 20  250.000000        mL        250.0             mL         NaN         NaN
# 21    1.000000      dose        250.0             mL         NaN         NaN
# 22    1.000000      dose          NaN            NaN         NaN         NaN
# 23    1.000000      dose          NaN            NaN         NaN         NaN
# 24   30.000000        mL         30.0             mL         NaN         NaN
# 25   30.000000        mL         30.0             mL         NaN         NaN
# 26  150.000000        mL        150.0             mL         NaN         NaN
# 27    1.000000      dose          NaN            NaN         NaN         NaN
# 28   10.000000        mL         10.0             mL         NaN         NaN
# 29   30.000000        mL         30.0             mL         NaN         NaN
# 30   50.000000        mL         50.0             mL         NaN         NaN
# 31    1.000000      dose         50.0             mL         NaN         NaN
# 32    1.000000      dose          NaN            NaN         NaN         NaN
# 33   55.833335        mL        400.0             mL   10.000000     mL/hour
# 34    1.000000      dose          NaN            NaN         NaN         NaN
# 35  500.000000        mL        500.0             mL         NaN         NaN
# 36  249.999990        mL        250.0             mL  249.999985     mL/hour
# 37  249.999990        mL        250.0             mL  249.999985     mL/hour
# 38  175.083339        mL       1000.0             mL    5.000000     mL/hour
# 39  999.999953        mg          NaN            NaN         NaN         NaN
# 40    0.515582        mg        250.0             mL    0.050012  mcg/kg/min
# 41   16.111952        mL        250.0             mL    4.538578     mL/hour
# 42   60.000000        mL         60.0             mL         NaN         NaN
# 43    1.000000      dose          NaN            NaN         NaN         NaN
# 44  200.000000        mL        200.0             mL         NaN         NaN
# 45    1.000000      dose        200.0             mL         NaN         NaN
# 46  100.000000        mL        100.0             mL         NaN         NaN
# 47    1.000000      dose        100.0             mL         NaN         NaN
# 48  205.894252        mL       1000.0             mL   34.996189     mL/hour
# 49  100.000000        mL        100.0             mL         NaN         NaN
#
#                            label
# 0                   Gastric Meds
# 1   Heparin Sodium (Prophylaxis)
# 2                       GT Flush
# 3                    Dextrose 5%
# 4                  Metronidazole
# 5                      NaCl 0.9%
# 6                     Vancomycin
# 7                   Gastric Meds
# 8                       GT Flush
# 9                    Dextrose 5%
# 10                      Cefepime
# 11                   Dextrose 5%
# 12                    Vancomycin
# 13                  Gastric Meds
# 14                      GT Flush
# 15  Heparin Sodium (Prophylaxis)
# 16                     NaCl 0.9%
# 17                    Vancomycin
# 18                  Gastric Meds
# 19                      GT Flush
# 20                   Dextrose 5%
# 21                    Vancomycin
# 22           Famotidine (Pepcid)
# 23  Heparin Sodium (Prophylaxis)
# 24                  Gastric Meds
# 25                      GT Flush
# 26                     PO Intake
# 27                    Vancomycin
# 28                  Gastric Meds
# 29                      GT Flush
# 30                   Dextrose 5%
# 31                      Cefepime
# 32  Heparin Sodium (Prophylaxis)
# 33           Peptamen 1.5 (Full)
# 34                    Vancomycin
# 35                     NaCl 0.9%
# 36                    Albumin 5%
# 37                    Albumin 5%
# 38                     NaCl 0.9%
# 39              Acetaminophen-IV
# 40                Norepinephrine
# 41                     NaCl 0.9%
# 42                      GT Flush
# 43  Heparin Sodium (Prophylaxis)
# 44                   Dextrose 5%
# 45                 Ciprofloxacin
# 46                   Dextrose 5%
# 47                     Meropenem
# 48          Isosource 1.5 (Full)
# 49                   Dextrose 5%

# %%
input.shape
# Out:
# (3174060, 12)

# %%
# Group by itemid and count nulls in both 'amount' and 'totalamount' columns
null_counts = input.groupby('itemid').agg(
    null_amount=('amount', lambda x: x.isnull().sum()),
    null_totalamount=('totalamount', lambda x: x.isnull().sum())
).reset_index()

null_counts
# Out:
#      itemid  null_amount  null_totalamount
# 0    220862            0                 0
# 1    220864            0                 0
# 2    220949            0                23
# 3    220950            0                 0
# 4    220952            0              4699
# ..      ...          ...               ...
# 306  229760            0                 0
# 307  229764            0                 0
# 308  229781            0                 0
# 309  229861            0                 0
# 310  230034            0                 0
#
# [311 rows x 3 columns]

# %%
# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column with null_counts using itemid
null_counts = null_counts.merge(
    d_items[['itemid', 'label']],  
    on='itemid',
    how='left' 
)

null_counts
# Out:
#      itemid  null_amount  null_totalamount                             label
# 0    220862            0                 0                       Albumin 25%
# 1    220864            0                 0                        Albumin 5%
# 2    220949            0                23                       Dextrose 5%
# 3    220950            0                 0                      Dextrose 10%
# 4    220952            0              4699                      Dextrose 50%
# ..      ...          ...               ...                               ...
# 306  229760            0                 0            Epoprostenol (Veletri)
# 307  229764            0                 0         Angiotensin II (Giapreza)
# 308  229781            0                 0  Bivalirudin (Angiomax) (Impella)
# 309  229861            0                 0                   Sodium Acetate.
# 310  230034            0                 0                Amiodarone 150/100
#
# [311 rows x 4 columns]

# %%
filtered_null_counts = null_counts[
    (null_counts['null_amount'] > 0) | (null_counts['null_totalamount'] > 0)
]

filtered_null_counts
# Out:
#      itemid  null_amount  null_totalamount                 label
# 2    220949            0                23           Dextrose 5%
# 4    220952            0              4699          Dextrose 50%
# 10   221282            0               135             Adenosine
# 14   221347            0              1380            Amiodarone
# 15   221385            0             12928    Lorazepam (Ativan)
# ..      ...          ...               ...                   ...
# 296  229616            0               185  Ondansetron (Zofran)
# 297  229617            0                23          Epinephrine.
# 298  229618            0                27      Calcium Chloride
# 299  229619            0                 3        Insulin - U500
# 303  229639            0               108    Bumetanide (Bumex)
#
# [113 rows x 4 columns]

# %%
pd.set_option('display.max_rows', None)     # Show all rows

filtered_null_counts
# Out:
#      itemid  null_amount  null_totalamount  \
# 2    220949            0                23
# 4    220952            0              4699
# 10   221282            0               135
# 14   221347            0              1380
# 15   221385            0             12928
# 16   221393            0               151
# 19   221468            0              1634
# 20   221555            0               504
# 21   221623            0              1344
# 53                     Insulin - Humalog 75/25
# 54                           Insulin - Humalog
# 59                              Heparin Sodium
# 60                                   Labetalol
# 61                            Morphine Sulfate
# 65                                   NaCl 0.9%
# 66                                  NaCl 0.45%
# 76                                  Free Water
# 77                                  Vancomycin
# 78                                Gastric Meds
# 83                                          LR
# 89                                   Acyclovir
# 94                                  Atovaquone
# 95                                Azithromycin
# 98                                   Cefazolin
# 99                                    Cefepime
# 100                                Ceftazidime
# 102                              Ciprofloxacin
# 103                                Clindamycin
# 107                               Erythromycin
# 108                                 Ethambutol
# 109                                Fluconazole
# 110                                  Foscarnet
# 114                                  Isoniazid
# 115                               Levofloxacin
# 116                                  Linezolid
# 118                              Metronidazole
# 119                                 Micafungin
# 120                               Moxifloxacin
# 121                                  Nafcillin
# 122                     Penicillin G potassium
# 125                               Pyrazinamide
# 126                                    Quinine
# 127                                   Rifampin
# 128                          Bactrim (SMX/TMP)
# 130                             Valgancyclovir
# 131                               Voriconazole
# 132                       Enoxaparin (Lovenox)
# 133                        Famotidine (Pepcid)
# 134                               Fondaparinux
# 135                    Lansoprazole (Prevacid)
# 136                    Pantoprazole (Protonix)
# 137                   Ranitidine (Prophylaxis)
# 138                      Carafate (Sucralfate)
# 139                        Coumadin (Warfarin)
# 140                                Factor VIIa
# 141                                 Profilnine
# 152                              Ensure (Full)
# 155                                   Solution
# 157                                  Lidocaine
# 162                       Meperidine (Demerol)
# 163                                 Metoprolol
# 164               Heparin Sodium (Prophylaxis)
# 165                                 Optisource
# 169  Vanilla Lactose Free Scandi Shake (mixed)
# 194               Pre-Admission/Non-ICU Intake
# 196                      OR Crystalloid Intake
# 197                          OR Colloid Intake
# 198                              OR FFP Intake
# 199                       OR Packed RBC Intake
# 200                         OR Platelet Intake
# 203                       OR Cell Saver Intake
# 207                                  PO Intake
# 208                                   GT Flush
# 218                    Methadone Hydrochloride
# 229              Sodium Bicarbonate 8.4% (Amp)
# 233                                   Dilantin
# 234                               Fosphenytoin
# 235                                     Keflex
# 237                      Omeprazole (Prilosec)
# 246                                    Tamiflu
# 253                           Acetaminophen-IV
# 254                     Levetiracetam (Keppra)
# 277                                Pamidronate
# 279                          Protamine sulfate
# 280                          Digoxin (Lanoxin)
# 281                    Glycopyrolate (Robinul)
# 282                   Neostigmine (Prostigmin)
# 283                        Ketorolac (Toradol)
# 284                                 Rocuronium
# 289                          Insulin - Novolog
# 291      Fiber Supplement (i.e. Banana Flakes)
# 292                               Beneprotein.
# 296                       Ondansetron (Zofran)
# 297                               Epinephrine.
# 298                           Calcium Chloride
# 299                             Insulin - U500
# 303                         Bumetanide (Bumex)

# %%
null_counts
# Out:
#      itemid  null_amount  null_totalamount  \
# 0    220862            0                 0
# 1    220864            0                 0
# 2    220949            0                23
# 3    220950            0                 0
# 4    220952            0              4699
# 5    220970            0                 0
# 6    220995            0                 0
# 7    221036            0                 0
# 8    221207            0                 0
# 9    221261            0                 0
# 10   221282            0               135
# 11   221289            0                 0
# 12   221319            0                 0
# 13   221342            0                 0
# 14   221347            0              1380
# 15   221385            0             12928
# 16   221393            0               151
# 17   221429            0                 0
# 284  229233            0               341
# 285  229234            0                 0
# 286  229295            0                 0
# 287  229296            0                 0
# 288  229297            0                 0
# 289  229299            0               242
# 290  229420            0                 0
# 291  229574            0                 4
# 292  229583            0                10
# 293  229587            0                 0
# 294  229597            0                 0
# 295  229615            0                 0
# 296  229616            0               185
# 297  229617            0                23
# 298  229618            0                27
# 299  229619            0                 3
# 300  229624            0                 0
# 301  229630            0                 0
# 302  229632            0                 0
# 303  229639            0               108
# 304  229640            0                 0
# 305  229654            0                 0
# 306  229760            0                 0
# 307  229764            0                 0
# 308  229781            0                 0
# 309  229861            0                 0
# 310  230034            0                 0
#
#                                          label
# 0                                  Albumin 25%
# 1                                   Albumin 5%
# 2                                  Dextrose 5%
# 3                                 Dextrose 10%
# 4                                 Dextrose 50%
# 5                          Fresh Frozen Plasma
# 6                      Sodium Bicarbonate 8.4%
# 7                          Nutren Renal (Full)
# 8                                Impact (Full)
# 9                           Abciximab (Reopro)
# 10                                   Adenosine
# 11                                 Epinephrine
# 12                             Alteplase (TPA)
# 13                               Aminophylline
# 14                                  Amiodarone
# 15                          Lorazepam (Ativan)
# 16                                    Atropine
# 17                                     Esmolol
# 18                           Calcium Gluconate
# 19                                   Diltiazem
# 20                               Cisatracurium
# 21                           Diazepam (Valium)
# 22                                  Dobutamine
# 23                                    Dopamine
# 24                          Midazolam (Versed)
# 25                        Drotrecogin (Xigris)
# 26                                    Ketamine
# 27                                 Factor VIII
# 28                                    Fentanyl
# 29                               Phenylephrine
# 30                          Furosemide (Lasix)
# 31                        Haloperidol (Haldol)
# 32                                 Hydralazine
# 33                    Hydromorphone (Dilaudid)
# 34                                   Lepirudin
# 35                              Norepinephrine
# 36                                   Milrinone
# 37                           Magnesium Sulfate
# 38                           Naloxone (Narcan)
# 39                                  Nesiritide
# 40                                 Nicardipine
# 41                               Nitroprusside
# 42                               Nitroglycerin
# 43                                  Vecuronium
# 44                                Procainamide
# 45                                    Propofol
# 46                                  Ranitidine
# 47                                 Vasopressin
# 48                                   Verapamil
# 49                             Insulin - 70/30
# 50                           Insulin - Regular
# 51                               Insulin - NPH
# 52                          Insulin - Glargine
# 53                     Insulin - Humalog 75/25
# 54                           Insulin - Humalog
# 55                                  Argatroban
# 56                      Bivalirudin (Angiomax)
# 57                  Dexmedetomidine (Precedex)
# 58                   Eptifibatide (Integrilin)
# 59                              Heparin Sodium
# 60                                   Labetalol
# 61                            Morphine Sulfate
# 62                                  Octreotide
# 63                               Pentobarbital
# 64                       Tirofiban (Aggrastat)
# 65                                   NaCl 0.9%
# 66                                  NaCl 0.45%
# 67                 NaCl 3% (Hypertonic Saline)
# 68                          Potassium Chloride
# 69                     Hydrochloric Acid - HCL
# 70                      Packed Red Blood Cells
# 71                                   Platelets
# 72                             Cryoprecipitate
# 73                                  Cell Saver
# 74                      Hetastarch (Hespan) 6%
# 75                                  Dextran 40
# 76                                  Free Water
# 77                                  Vancomycin
# 78                                Gastric Meds
# 79                                  Lipids 20%
# 80                                    D5 1/2NS
# 81                                        D5NS
# 82                                        D5LR
# 83                                          LR
# 84                               Multivitamins
# 85                                  Folic Acid
# 86                                    Thiamine
# 87                                      K Phos
# 88                                     Na Phos
# 89                                   Acyclovir
# 90                                    Ambisome
# 91                                    Amikacin
# 92                                  Ampicillin
# 93               Ampicillin/Sulbactam (Unasyn)
# 94                                  Atovaquone
# 95                                Azithromycin
# 96                                   Aztreonam
# 97                                 Caspofungin
# 98                                   Cefazolin
# 99                                    Cefepime
# 100                                Ceftazidime
# 101                                Ceftriaxone
# 102                              Ciprofloxacin
# 103                                Clindamycin
# 104                                   Colistin
# 105                                 Daptomycin
# 106                                Doxycycline
# 107                               Erythromycin
# 108                                 Ethambutol
# 109                                Fluconazole
# 110                                  Foscarnet
# 111                                Gancyclovir
# 112                                 Gentamicin
# 113                        Imipenem/Cilastatin
# 114                                  Isoniazid
# 115                               Levofloxacin
# 116                                  Linezolid
# 117                                  Meropenem
# 118                              Metronidazole
# 119                                 Micafungin
# 120                               Moxifloxacin
# 121                                  Nafcillin
# 122                     Penicillin G potassium
# 123                               Piperacillin
# 124            Piperacillin/Tazobactam (Zosyn)
# 125                               Pyrazinamide
# 126                                    Quinine
# 127                                   Rifampin
# 128                          Bactrim (SMX/TMP)
# 129                                 Tobramycin
# 130                             Valgancyclovir
# 131                               Voriconazole
# 132                       Enoxaparin (Lovenox)
# 133                        Famotidine (Pepcid)
# 134                               Fondaparinux
# 135                    Lansoprazole (Prevacid)
# 136                    Pantoprazole (Protonix)
# 137                   Ranitidine (Prophylaxis)
# 138                      Carafate (Sucralfate)
# 139                        Coumadin (Warfarin)
# 140                                Factor VIIa
# 141                                 Profilnine
# 142                              TPN w/ Lipids
# 143                         TPN without Lipids
# 144            Peripheral Parenteral Nutrition
# 145                   Impact with Fiber (Full)
# 146                          ProBalance (Full)
# 147                        Peptamen 1.5 (Full)
# 148                          Nutren 2.0 (Full)
# 149                             Vivonex (Full)
# 150                             Replete (Full)
# 151                  Replete with Fiber (Full)
# 152                              Ensure (Full)
# 153                                   D5 1/4NS
# 154                     Fentanyl (Concentrate)
# 155                                   Solution
# 156                              Sterile Water
# 157                                  Lidocaine
# 158                                Dextrose PN
# 159                                Amino Acids
# 160                          Lipids (additive)
# 161                                Beneprotein
# 162                       Meperidine (Demerol)
# 163                                 Metoprolol
# 164               Heparin Sodium (Prophylaxis)
# 165                                 Optisource
# 166          Mighty Shake (Vanilla/Strawberry)
# 167                   Mighty Shake (Chocolate)
# 168              Mighty Shake (no sugar added)
# 169  Vanilla Lactose Free Scandi Shake (mixed)
# 170                           Nutren 2.0 (1/4)
# 171                           Nutren 2.0 (2/3)
# 172                           Nutren 2.0 (1/2)
# 173                               Impact (3/4)
# 174                               Impact (1/2)
# 175                    Impact with Fiber (1/4)
# 176                    Impact with Fiber (3/4)
# 177                    Impact with Fiber (1/2)
# 178                         Nutren Renal (3/4)
# 179                         Nutren Renal (1/2)
# 180                         Peptamen 1.5 (1/4)
# 181                         Peptamen 1.5 (3/4)
# 182                         Peptamen 1.5 (1/2)
# 183                              Replete (1/4)
# 184                              Replete (2/3)
# 185                              Replete (3/4)
# 186                              Replete (1/2)
# 187                   Replete with Fiber (1/4)
# 188                   Replete with Fiber (2/3)
# 189                   Replete with Fiber (3/4)
# 190                   Replete with Fiber (1/2)
# 191                              Vivonex (3/4)
# 192                              Vivonex (1/2)
# 193                                  Piggyback
# 194               Pre-Admission/Non-ICU Intake
# 195                            Cath Lab Intake
# 196                      OR Crystalloid Intake
# 197                          OR Colloid Intake
# 198                              OR FFP Intake
# 199                       OR Packed RBC Intake
# 200                         OR Platelet Intake
# 201                 OR Autologous Blood Intake
# 202                  OR Cryoprecipitate Intake
# 203                       OR Cell Saver Intake
# 204                    PACU Crystalloid Intake
# 205                        PACU Colloid Intake
# 206                             PACU PO Intake
# 207                                  PO Intake
# 208                                   GT Flush
# 209                         Ensure Plus (Full)
# 210                    Nutren Pulmonary (Full)
# 211                     Nutren Pulmonary (3/4)
# 212                     Nutren Pulmonary (1/2)
# 213                     PACU Packed RBC Intake
# 214                       PACU Platelet Intake
# 215                            PACU FFP Intake
# 216                                 Lipids 10%
# 217                           Nutren 2.0 (3/4)
# 218                    Methadone Hydrochloride
# 219                                KCL (Bolus)
# 220                  Magnesium Sulfate (Bolus)
# 221                 Magnesium Sulfate (OB-GYN)
# 222                   Calcium Gluconate (CRRT)
# 223                                    Citrate
# 224                      ACD-A Citrate (500ml)
# 225                     ACD-A Citrate (1000ml)
# 226                  IV Immune Globulin (IVIG)
# 227                                   Mannitol
# 228                            Plasma Pheresis
# 229              Sodium Bicarbonate 8.4% (Amp)
# 230                               Cyclosporine
# 231                   Vitamin K (Phytonadione)
# 232                                 KCl (CRRT)
# 233                                   Dilantin
# 234                               Fosphenytoin
# 235                                     Keflex
# 236                                    Isuprel
# 237                      Omeprazole (Prilosec)
# 238                      Fibersource HN (Full)
# 239                       Fibersource HN (3/4)
# 240                       Fibersource HN (1/2)
# 241                     NovaSource Renal (1/2)
# 242                     NovaSource Renal (3/4)
# 243                    NovaSource Renal (Full)
# 244                Boost Glucose Control (1/2)
# 245               Boost Glucose Control (Full)
# 246                                    Tamiflu
# 247                        Isosource 1.5 (1/2)
# 248                        Isosource 1.5 (1/4)
# 249                        Isosource 1.5 (3/4)
# 250                       Isosource 1.5 (Full)
# 251                               Dextrose 20%
# 252                               Dextrose 40%
# 253                           Acetaminophen-IV
# 254                     Levetiracetam (Keppra)
# 255                         Amiodarone 600/500
# 256                  Furosemide (Lasix) 250/50
# 257                                 NaCl 23.4%
# 258                                Nepro (1/2)
# 259                               Nepro (Full)
# 260                              Enlive (Full)
# 261                            Glucerna (Full)
# 262                            Pulmocare (1/4)
# 263                           Pulmocare (Full)
# 264                           Two Cal HN (1/2)
# 265                          Two Cal HN (Full)
# 266                  Peptamen Bariatric (Full)
# 267                             Promote (Full)
# 268                          Jevity 1.2 (Full)
# 269                          Jevity 1.5 (Full)
# 270                           Vital 1.5 (Full)
# 271                        Glucerna 1.2 (Full)
# 272                  Promote with Fiber (Full)
# 273                             Acetylcysteine
# 274                 Aminocaproic acid (Amicar)
# 275                  Ertapenem sodium (Invanz)
# 276           Mycophenolate mofetil (Cellcept)
# 277                                Pamidronate
# 278                                Tigecycline
# 279                          Protamine sulfate
# 280                          Digoxin (Lanoxin)
# 281                    Glycopyrolate (Robinul)
# 282                   Neostigmine (Prostigmin)
# 283                        Ketorolac (Toradol)
# 284                                 Rocuronium
# 285                    Clevidipine (Cleviprex)
# 286                        Glucerna 1.5 (Full)
# 287                  Vital High Protein (Full)
# 288                        Osmolite 1.5 (Full)
# 289                          Insulin - Novolog
# 290                 Dexmedetomidine (Precedex)
# 291      Fiber Supplement (i.e. Banana Flakes)
# 292                               Beneprotein.
# 293                                Ceftaroline
# 294                   Heparin Sodium (Impella)
# 295                      Esomeprazole (Nexium)
# 296                       Ondansetron (Zofran)
# 297                               Epinephrine.
# 298                           Calcium Chloride
# 299                             Insulin - U500
# 300                       Nicardipine 40mg/200
# 301                     Phenylephrine (50/250)
# 302                    Phenylephrine (200/250)
# 303                         Bumetanide (Bumex)
# 304                  Calcium Gluconate (Bolus)
# 305                         Amiodarone 450/250
# 306                     Epoprostenol (Veletri)
# 307                  Angiotensin II (Giapreza)
# 308           Bivalirudin (Angiomax) (Impella)
# 309                            Sodium Acetate.
# 310                         Amiodarone 150/100

# %%
input2 = input.copy()

pd.reset_option('display.max_rows')

# %%
input2 = input2.dropna(subset=['totalamount'], how='all')

input2.head(10)
# Out:
#     subject_id   stay_id           starttime             endtime  itemid  \
# 0     10002428  34807493 2156-05-01 08:00:00 2156-05-01 08:01:00  225799
# 2     10002428  34807493 2156-05-01 08:00:00 2156-05-01 08:01:00  226453
# 3     10002428  34807493 2156-05-01 10:00:00 2156-05-01 10:01:00  220949
# 4     10002428  34807493 2156-05-01 10:00:00 2156-05-01 10:01:00  225884
# 5     10002428  34807493 2156-05-01 11:15:00 2156-05-01 11:16:00  225158
# 7     10002428  34807493 2156-05-01 12:00:00 2156-05-01 12:01:00  225799
# 8     10002428  34807493 2156-05-01 12:00:00 2156-05-01 12:01:00  226453
# 9     10002428  34807493 2156-05-01 13:12:00 2156-05-01 13:13:00  220949
# 10    10002428  34807493 2156-05-01 13:12:00 2156-05-01 13:13:00  225851
# 11    10002428  34807493 2156-05-01 13:45:00 2156-05-01 13:46:00  220949
#
#     amount amountuom  totalamount totalamountuom  rate rateuom          label
# 0     30.0        mL         30.0             mL   NaN     NaN   Gastric Meds
# 2     50.0        mL         50.0             mL   NaN     NaN       GT Flush
# 3    100.0        mL        100.0             mL   NaN     NaN    Dextrose 5%
# 4      1.0      dose        100.0             mL   NaN     NaN  Metronidazole
# 5    500.0        mL        500.0             mL   NaN     NaN      NaCl 0.9%
# 7     10.0        mL         10.0             mL   NaN     NaN   Gastric Meds
# 8     30.0        mL         30.0             mL   NaN     NaN       GT Flush
# 9     50.0        mL         50.0             mL   NaN     NaN    Dextrose 5%
# 10     1.0      dose         50.0             mL   NaN     NaN       Cefepime
# 11   200.0        mL        200.0             mL   NaN     NaN    Dextrose 5%

# %%
input2.shape
# Out:
# (2686843, 12)

# %%
# Average, minimum and maximum time of each individual in dataframe

# Group by subject_id and calculate duration per subject
duration_per_subject = input2.groupby('subject_id')['starttime'].agg(['min', 'max'])
duration_per_subject['duration_hours'] = (
    (duration_per_subject['max'] - duration_per_subject['min']).dt.total_seconds() / 3600
)

# Summary statistics
average_duration = duration_per_subject['duration_hours'].mean()
min_duration = duration_per_subject['duration_hours'].min()
max_duration = duration_per_subject['duration_hours'].max()

print(f"🟢 Average time span per subject: {average_duration:.2f} hours")
print(f"🔵 Shortest time span: {min_duration:.2f} hours")
print(f"🔴 Longest time span: {max_duration:.2f} hours")
# Out:
# 🟢 Average time span per subject: 6389.53 hours
# 🔵 Shortest time span: 10.77 hours
# 🔴 Longest time span: 112126.53 hours

# %%
# Group by itemid
grouped = input2.groupby('itemid')

# Define the frequency function
def avg_obs_per_20_hours(group):
    n_obs = len(group)
    time_span_hours = (group['starttime'].max() - group['starttime'].min()).total_seconds() / 3600
    return (n_obs / time_span_hours * 20) if time_span_hours > 0 else float('nan')

# Apply the function to the cleaned dataframe
avg_freq_df = grouped.apply(avg_obs_per_20_hours).reset_index(name='avg_obs_per_20_hours')

avg_freq_df
# Out:
# /var/folders/ks/xzsx5z1n0zv653847sbsxy7r0000gp/T/ipykernel_83583/1687938942.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   avg_freq_df = grouped.apply(avg_obs_per_20_hours).reset_index(name='avg_obs_per_20_hours')
#      itemid  avg_obs_per_20_hours
# 0    220862              0.229405
# 1    220864              0.178425
# 2    220949              8.206738
# 3    220950              0.038730
# 4    220970              0.160001
# ..      ...                   ...
# 263  229760              0.000502
# 264  229764              0.001519
# 265  229781              0.001145
# 266  229861                   NaN
# 267  230034              0.000160
#
# [268 rows x 2 columns]

# %%
# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column with null_counts using itemid
avg_freq_df = avg_freq_df.merge(
    d_items[['itemid', 'label']],  
    on='itemid',
    how='left' 
)

avg_freq_df
# Out:
#      itemid  avg_obs_per_20_hours                             label
# 0    220862              0.229405                       Albumin 25%
# 1    220864              0.178425                        Albumin 5%
# 2    220949              8.206738                       Dextrose 5%
# 3    220950              0.038730                      Dextrose 10%
# 4    220970              0.160001               Fresh Frozen Plasma
# ..      ...                   ...                               ...
# 263  229760              0.000502            Epoprostenol (Veletri)
# 264  229764              0.001519         Angiotensin II (Giapreza)
# 265  229781              0.001145  Bivalirudin (Angiomax) (Impella)
# 266  229861                   NaN                   Sodium Acetate.
# 267  230034              0.000160                Amiodarone 150/100
#
# [268 rows x 3 columns]

# %%
# Dropping features that are measured < 0.1 times per 20-hour period

# Identify low-frequency itemids
low_freq_itemids = avg_freq_df[avg_freq_df['avg_obs_per_20_hours'] < 0.1]['itemid'].tolist()

# Drop them from input2
input3 = input2[~input2['itemid'].isin(low_freq_itemids)].copy()

# %%
input3.head()
# Out:
#    subject_id   stay_id           starttime             endtime  itemid  \
# 0    10002428  34807493 2156-05-01 08:00:00 2156-05-01 08:01:00  225799
# 2    10002428  34807493 2156-05-01 08:00:00 2156-05-01 08:01:00  226453
# 3    10002428  34807493 2156-05-01 10:00:00 2156-05-01 10:01:00  220949
# 4    10002428  34807493 2156-05-01 10:00:00 2156-05-01 10:01:00  225884
# 5    10002428  34807493 2156-05-01 11:15:00 2156-05-01 11:16:00  225158
#
#    amount amountuom  totalamount totalamountuom  rate rateuom          label
# 0    30.0        mL         30.0             mL   NaN     NaN   Gastric Meds
# 2    50.0        mL         50.0             mL   NaN     NaN       GT Flush
# 3   100.0        mL        100.0             mL   NaN     NaN    Dextrose 5%
# 4     1.0      dose        100.0             mL   NaN     NaN  Metronidazole
# 5   500.0        mL        500.0             mL   NaN     NaN      NaCl 0.9%

# %%
input3.shape
# Out:
# (2505890, 12)

# %%
input3 = input3[['subject_id', 'stay_id', 'starttime', 'itemid', 'totalamount', 'totalamountuom', 'label']]

input3.head()
# Out:
#    subject_id   stay_id           starttime  itemid  totalamount  \
# 0    10002428  34807493 2156-05-01 08:00:00  225799         30.0
# 2    10002428  34807493 2156-05-01 08:00:00  226453         50.0
# 3    10002428  34807493 2156-05-01 10:00:00  220949        100.0
# 4    10002428  34807493 2156-05-01 10:00:00  225884        100.0
# 5    10002428  34807493 2156-05-01 11:15:00  225158        500.0
#
#   totalamountuom          label
# 0             mL   Gastric Meds
# 2             mL       GT Flush
# 3             mL    Dextrose 5%
# 4             mL  Metronidazole
# 5             mL      NaCl 0.9%

# %%
# Check for outliers in the dataframe

summary_stats = input3.groupby('itemid')['totalamount'].agg(
    min_value='min',
    max_value='max',
    median_value='median'
).reset_index()

# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column with null_counts using itemid
summary_stats = summary_stats.merge(
    d_items[['itemid', 'label']],  
    on='itemid',
    how='left' 
)

print(summary_stats)
# Out:
#     itemid  min_value  max_value  median_value                       label
# 0   220862     10.000     1000.0          50.0                 Albumin 25%
# 1   220864     41.667     1000.0         250.0                  Albumin 5%
# 2   220949      0.500    10000.0         200.0                 Dextrose 5%
# 3   220970     30.000     3266.0         298.0         Fresh Frozen Plasma
# 4   221289     50.000      250.0         250.0                 Epinephrine
# ..     ...        ...        ...           ...                         ...
# 73  228364   1000.000     1000.0        1000.0            Two Cal HN (1/2)
# 74  229011     40.000     9000.0        1000.0           Jevity 1.5 (Full)
# 75  229420     30.000      250.0         100.0  Dexmedetomidine (Precedex)
# 76  229630    250.000      250.0         250.0      Phenylephrine (50/250)
# 77  229861     50.000       50.0          50.0             Sodium Acetate.
#
# [78 rows x 5 columns]

# %%
# Subsetting data to identify reference ranges

input3_subset = input3[input3['itemid'] == 229011]
input3_subset
# Out:
#          subject_id   stay_id           starttime  itemid  totalamount  \
# 6952       10020740  35889503 2150-03-26 20:00:00  229011       1000.0
# 6966       10020740  35889503 2150-03-27 22:18:00  229011       1000.0
# 6968       10020740  35889503 2150-03-28 02:16:00  229011       1000.0
# 6972       10020740  35889503 2150-03-28 05:45:00  229011       1000.0
# 6981       10020740  35889503 2150-03-26 16:23:00  229011       1000.0
# ...             ...       ...                 ...     ...          ...
# 3173945    19998843  30988867 2187-02-07 04:38:00  229011       1000.0
# 3173969    19998843  30988867 2187-02-07 10:00:00  229011       1000.0
# 3173978    19998843  30988867 2187-02-07 18:05:00  229011       1000.0
# 3174037    19998843  30988867 2187-02-06 12:28:00  229011       1000.0
# 3174043    19998843  30988867 2187-02-06 16:41:00  229011       1000.0
#
#         totalamountuom              label
# 6952                mL  Jevity 1.5 (Full)
# 6966                mL  Jevity 1.5 (Full)
# 6968                mL  Jevity 1.5 (Full)
# 6972                mL  Jevity 1.5 (Full)
# 6981                mL  Jevity 1.5 (Full)
# ...                ...                ...
# 3173945             mL  Jevity 1.5 (Full)
# 3173969             mL  Jevity 1.5 (Full)
# 3173978             mL  Jevity 1.5 (Full)
# 3174037             mL  Jevity 1.5 (Full)
# 3174043             mL  Jevity 1.5 (Full)
#
# [4722 rows x 7 columns]

# %%
# Copy the original DataFrame
input4 = input3.copy()

# Define the reference ranges
valid_ranges = {
    220949: (0, 1000),
    220970: (0, 500),
    221906: (0, 300),
    222011: (0, 250),
    222042: (0, 300),
    222168: (0, 200),
    223258: (0, 2000),
    225152: (0, 500),
    225158: (0, 1000),
    225166: (0, 1000),
    225168: (0, 500),
    225797: (0, 500),
    225798: (0, 500),
    225799: (0, 500),
    225823: (0, 1000),
    225828: (0, 1000),
    225936: (0, 1000),
    225943: (0, 1000),
    225944: (0, 1000),
    225970: (0, 2000),
    226089: (0, 1000),
    226452: (0, 500),
    226453: (0, 500),
    226880: (0, 1000),
    227526: (0, 1000),
    227529: (0, 1000),
    228351: (0, 2000),
    229011: (0, 1000),
}

# Separate into rows with itemids in valid_ranges and the rest
to_filter = input4[input4['itemid'].isin(valid_ranges.keys())].copy()
to_keep = input4[~input4['itemid'].isin(valid_ranges.keys())].copy()

# Apply filtering to to_filter
def in_valid_range(row):
    low, high = valid_ranges[row['itemid']]
    return low <= row['totalamount'] <= high

filtered = to_filter[to_filter.apply(in_valid_range, axis=1)]

# Concatenate the filtered and unfiltered subsets
input4 = pd.concat([filtered, to_keep], ignore_index=True)

# %%
input4.head()
# Out:
#    subject_id   stay_id           starttime  itemid  totalamount  \
# 0    10002428  34807493 2156-05-01 08:00:00  225799         30.0
# 1    10002428  34807493 2156-05-01 08:00:00  226453         50.0
# 2    10002428  34807493 2156-05-01 10:00:00  220949        100.0
# 3    10002428  34807493 2156-05-01 11:15:00  225158        500.0
# 4    10002428  34807493 2156-05-01 12:00:00  225799         10.0
#
#   totalamountuom         label
# 0             mL  Gastric Meds
# 1             mL      GT Flush
# 2             mL   Dextrose 5%
# 3             mL     NaCl 0.9%
# 4             mL  Gastric Meds

# %%
input4.shape
# Out:
# (2500032, 7)

# %%
# Check for outliers in the dataframe

summary_stats = input4.groupby('itemid')['totalamount'].agg(
    min_value='min',
    max_value='max',
    median_value='median'
).reset_index()

# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column with null_counts using itemid
summary_stats = summary_stats.merge(
    d_items[['itemid', 'label']],  
    on='itemid',
    how='left' 
)

print(summary_stats)
# Out:
#     itemid  min_value  max_value  median_value                       label
# 0   220862     10.000     1000.0          50.0                 Albumin 25%
# 1   220864     41.667     1000.0         250.0                  Albumin 5%
# 2   220949      0.500     1000.0         200.0                 Dextrose 5%
# 3   220970     30.000      500.0         298.0         Fresh Frozen Plasma
# 4   221289     50.000      250.0         250.0                 Epinephrine
# ..     ...        ...        ...           ...                         ...
# 73  228364   1000.000     1000.0        1000.0            Two Cal HN (1/2)
# 74  229011     40.000     1000.0        1000.0           Jevity 1.5 (Full)
# 75  229420     30.000      250.0         100.0  Dexmedetomidine (Precedex)
# 76  229630    250.000      250.0         250.0      Phenylephrine (50/250)
# 77  229861     50.000       50.0          50.0             Sodium Acetate.
#
# [78 rows x 5 columns]

# %%
input5 = input4.copy()

# %%
# Create dataframe which sums 24h input

# Make a copy of the dataframe
input6 = input5.copy()

# Extract the date part for grouping
input6['start_date'] = input6['starttime'].dt.date

# Group by subject_id, stay_id, and start_date
input6 = (
    input6
    .groupby(['subject_id', 'stay_id', 'start_date'])
    .agg(
        starttime=('starttime', 'min'),         # earliest time in the day
        totalamount=('totalamount', 'sum')      # total input in 24h
    )
    .reset_index()
    .rename(columns={'totalamount': '24h_input'})
)

input6.head()
# Out:
#    subject_id   stay_id  start_date           starttime  24h_input
# 0    10002428  33987268  2156-04-12 2156-04-12 17:30:00     2900.0
# 1    10002428  33987268  2156-04-13 2156-04-13 00:00:00     6440.0
# 2    10002428  33987268  2156-04-14 2156-04-14 03:04:00     6150.0
# 3    10002428  33987268  2156-04-15 2156-04-15 00:10:00     2040.0
# 4    10002428  33987268  2156-04-16 2156-04-16 05:13:00      800.0

# %%
input6.shape
# Out:
# (82296, 5)

# %%
file_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/outputevents.csv'

# Load the CSV into a DataFrame
output = pd.read_csv(file_path)

# Display the first few rows to confirm it loaded correctly
print(output.head())
# Out:
#    subject_id   stay_id  itemid            charttime  value valueuom
# 0    10002428  34807493  226559  2156-05-01 07:00:00   35.0       mL
# 1    10002428  34807493  226559  2156-05-01 08:00:00   35.0       mL
# 2    10002428  34807493  226559  2156-05-01 09:00:00   35.0       mL
# 3    10002428  34807493  226559  2156-05-01 10:00:00   35.0       mL
# 4    10002428  34807493  226559  2156-05-01 11:00:00   35.0       mL

# %%
output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379313 entries, 0 to 1379312
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   subject_id  1379313 non-null  int64
#  1   stay_id     1379313 non-null  int64
#  2   itemid      1379313 non-null  int64
#  3   charttime   1379313 non-null  object
#  4   value       1379313 non-null  float64
#  5   valueuom    1379313 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 63.1+ MB

# %%
# Convert charttime to an datetime
output['charttime'] = output['charttime'].astype('datetime64[ns]')
output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379313 entries, 0 to 1379312
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   subject_id  1379313 non-null  int64
#  1   stay_id     1379313 non-null  int64
#  2   itemid      1379313 non-null  int64
#  3   charttime   1379313 non-null  datetime64[ns]
#  4   value       1379313 non-null  float64
#  5   valueuom    1379313 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 63.1+ MB

# %%
# Count the number of unique subject_ids / patients in this dataframe
print(f'Number of patients: {output["subject_id"].nunique()}')
# Out:
# Number of patients: 5825

# %%
# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column into the ventilation dataframe using itemid
output = output.merge(
    d_items[['itemid', 'label']],  # Only keep necessary columns
    on='itemid',
    how='left'  # Keep all rows from ventilation
)

# %%
output.head(10)
# Out:
#    subject_id   stay_id  itemid           charttime  value valueuom  label
# 0    10002428  34807493  226559 2156-05-01 07:00:00   35.0       mL  Foley
# 1    10002428  34807493  226559 2156-05-01 08:00:00   35.0       mL  Foley
# 2    10002428  34807493  226559 2156-05-01 09:00:00   35.0       mL  Foley
# 3    10002428  34807493  226559 2156-05-01 10:00:00   35.0       mL  Foley
# 4    10002428  34807493  226559 2156-05-01 11:00:00   35.0       mL  Foley
# 5    10002428  34807493  226559 2156-05-01 12:00:00   15.0       mL  Foley
# 6    10002428  34807493  226559 2156-05-01 13:00:00   20.0       mL  Foley
# 7    10002428  34807493  226559 2156-05-01 14:00:00   20.0       mL  Foley
# 8    10002428  34807493  226559 2156-05-01 15:00:00   30.0       mL  Foley
# 9    10002428  34807493  226559 2156-05-01 16:00:00   30.0       mL  Foley

# %%
# Group by itemid and count nulls in 'value' column
null_counts = output.groupby('itemid').agg(
    null_value=('value', lambda x: x.isnull().sum()),
).reset_index()

# %%
null_counts
# Out:
#     itemid  null_value
# 0   226557           0
# 1   226558           0
# 2   226559           0
# 3   226560           0
# 4   226561           0
# ..     ...         ...
# 66  227510           0
# 67  227511           0
# 68  227701           0
# 69  229413           0
# 70  229414           0
#
# [71 rows x 2 columns]

# %%
# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column with null_counts using itemid
null_counts = null_counts.merge(
    d_items[['itemid', 'label']],  
    on='itemid',
    how='left' 
)

null_counts
# Out:
#     itemid  null_value               label
# 0   226557           0    R Ureteral Stent
# 1   226558           0    L Ureteral Stent
# 2   226559           0               Foley
# 3   226560           0                Void
# 4   226561           0         Condom Cath
# ..     ...         ...                 ...
# 66  227510           0         TF Residual
# 67  227511           0  TF Residual Output
# 68  227701           0        Drainage Bag
# 69  229413           0       Chest Tube #3
# 70  229414           0       Chest Tube #4
#
# [71 rows x 3 columns]

# %%
filtered_null_counts = null_counts[
    (null_counts['null_value'] > 0)]

filtered_null_counts
# Out:
# Empty DataFrame
# Columns: [itemid, null_value, label]
# Index: []

# %%
pd.set_option('display.max_rows', None)     # Show all rows

null_counts
# Out:
#     itemid  null_value                         label
# 0   226557           0              R Ureteral Stent
# 1   226558           0              L Ureteral Stent
# 2   226559           0                         Foley
# 3   226560           0                          Void
# 4   226561           0                   Condom Cath
# 5   226563           0                    Suprapubic
# 6   226564           0                 R Nephrostomy
# 7   226565           0                 L Nephrostomy
# 8   226567           0                 Straight Cath
# 9   226569           0            Anderson (gastric)
# 10  226570           0                     Blakemore
# 11  226571           0                        Emesis
# 12  226572           0                         Ewald
# 13  226573           0                  Gastric Tube
# 14  226574           0                   Jejunostomy
# 15  226575           0                   Nasogastric
# 16  226576           0                  Oral Gastric
# 17  226579           0                         Stool
# 18  226580           0                     Fecal Bag
# 19  226582           0               Ostomy (output)
# 20  226583           0                   Rectal Tube
# 21  226584           0                   Ileoconduit
# 22  226588           0                 Chest Tube #1
# 23  226589           0                 Chest Tube #2
# 24  226590           0                  L Pleural #1
# 25  226591           0                  L Pleural #2
# 26  226592           0                   Mediastinal
# 27  226593           0                  R Pleural #1
# 28  226595           0                  R Pleural #2
# 29  226597           0                     JP Medial
# 30  226598           0                    JP Lateral
# 31  226599           0              Jackson Pratt #1
# 32  226600           0              Jackson Pratt #2
# 33  226601           0              Jackson Pratt #3
# 34  226602           0              Jackson Pratt #4
# 35  226603           0                        T Tube
# 36  226604           0                    Hemovac #1
# 37  226605           0                    Hemovac #2
# 38  226606           0       Cerebral Ventricular #1
# 39  226607           0       Cerebral Ventricular #2
# 40  226608           0          Cerebral Subdural #1
# 41  226609           0          Cerebral Subdural #2
# 42  226610           0                        Lumbar
# 43  226612           0                   Pericardial
# 44  226613           0                  Wound Vac #1
# 45  226614           0                  Wound Vac #2
# 46  226616           0                      Anderson
# 47  226617           0                       Sump #1
# 48  226618           0                       Sump #2
# 49  226619           0                    Pigtail #1
# 50  226620           0                    Pigtail #2
# 51  226621           0                         Davol
# 52  226622           0                    Red Rubber
# 53  226623           0                    Penrose #1
# 54  226624           0                    Penrose #2
# 55  226625           0                           Tap
# 56  226626           0                        OR EBL
# 57  226627           0                      OR Urine
# 58  226628           0                   PACU Drains
# 59  226629           0                      PACU EBL
# 60  226630           0                  PACU Gastric
# 61  226631           0                    PACU Urine
# 62  226632           0                      Cath Lab
# 63  226633           0                 Pre-Admission
# 64  227488           0         GU Irrigant Volume In
# 65  227489           0  GU Irrigant/Urine Volume Out
# 66  227510           0                   TF Residual
# 67  227511           0            TF Residual Output
# 68  227701           0                  Drainage Bag
# 69  229413           0                 Chest Tube #3
# 70  229414           0                 Chest Tube #4

# %%
output2 = output.copy()

pd.reset_option('display.max_rows')

# %%
# Group by itemid
grouped = output2.groupby('itemid')

# Define the frequency function
def avg_obs_per_20_hours(group):
    n_obs = len(group)
    time_span_hours = (group['charttime'].max() - group['charttime'].min()).total_seconds() / 3600
    return (n_obs / time_span_hours * 20) if time_span_hours > 0 else float('nan')

# Apply the function to the cleaned dataframe
avg_freq_df = grouped.apply(avg_obs_per_20_hours).reset_index(name='avg_obs_per_20_hours')

avg_freq_df
# Out:
# /var/folders/ks/xzsx5z1n0zv653847sbsxy7r0000gp/T/ipykernel_83583/1680393632.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   avg_freq_df = grouped.apply(avg_obs_per_20_hours).reset_index(name='avg_obs_per_20_hours')
#     itemid  avg_obs_per_20_hours
# 0   226557              0.008882
# 1   226558              0.002945
# 2   226559             23.324210
# 3   226560              0.702340
# 4   226561              0.192176
# ..     ...                   ...
# 66  227510              0.853695
# 67  227511              0.088838
# 68  227701              0.140177
# 69  229413              0.010207
# 70  229414              3.399433
#
# [71 rows x 2 columns]

# %%
# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column with null_counts using itemid
avg_freq_df = avg_freq_df.merge(
    d_items[['itemid', 'label']],  
    on='itemid',
    how='left' 
)

avg_freq_df
# Out:
#     itemid  avg_obs_per_20_hours               label
# 0   226557              0.008882    R Ureteral Stent
# 1   226558              0.002945    L Ureteral Stent
# 2   226559             23.324210               Foley
# 3   226560              0.702340                Void
# 4   226561              0.192176         Condom Cath
# ..     ...                   ...                 ...
# 66  227510              0.853695         TF Residual
# 67  227511              0.088838  TF Residual Output
# 68  227701              0.140177        Drainage Bag
# 69  229413              0.010207       Chest Tube #3
# 70  229414              3.399433       Chest Tube #4
#
# [71 rows x 3 columns]

# %%
# Dropping features that are measured < 0.1 times per 20-hour period

# Identify low-frequency itemids
low_freq_itemids = avg_freq_df[avg_freq_df['avg_obs_per_20_hours'] < 0.1]['itemid'].tolist()

# Drop them from output2
output3 = output2[~output2['itemid'].isin(low_freq_itemids)].copy()

output3.shape
# Out:
# (1315294, 7)

# %%
output3 = output3[['subject_id', 'stay_id', 'itemid', 'charttime', 'value', 'label']]

output3.head()
# Out:
#    subject_id   stay_id  itemid           charttime  value  label
# 0    10002428  34807493  226559 2156-05-01 07:00:00   35.0  Foley
# 1    10002428  34807493  226559 2156-05-01 08:00:00   35.0  Foley
# 2    10002428  34807493  226559 2156-05-01 09:00:00   35.0  Foley
# 3    10002428  34807493  226559 2156-05-01 10:00:00   35.0  Foley
# 4    10002428  34807493  226559 2156-05-01 11:00:00   35.0  Foley

# %%
# Check for outliers in the dataframe

summary_stats = output3.groupby('itemid')['value'].agg(
    min_value='min',
    max_value='max',
    median_value='median'
).reset_index()

# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column with null_counts using itemid
summary_stats = summary_stats.merge(
    d_items[['itemid', 'label']],  
    on='itemid',
    how='left' 
)

print(summary_stats)
# Out:
#     itemid  min_value  max_value  median_value                    label
# 0   226559        0.0    25025.0          80.0                    Foley
# 1   226560        0.0     2600.0         250.0                     Void
# 2   226561        0.0     1900.0         175.0              Condom Cath
# 3   226572        0.0      700.0         250.0                    Ewald
# 4   226575        0.0    15000.0         100.0              Nasogastric
# 5   226576        0.0     3000.0         100.0             Oral Gastric
# 6   226579       -1.0     4000.0         200.0                    Stool
# 7   226580      -45.0     2000.0         300.0                Fecal Bag
# 8   226582        0.0     2000.0         150.0          Ostomy (output)
# 9   226588      -30.0     3000.0          25.0            Chest Tube #1
# 10  226589      -30.0     2500.0          20.0            Chest Tube #2
# 11  226590      -30.0     2160.0          20.0             L Pleural #1
# 12  226597        0.0     2300.0          50.0                JP Medial
# 13  226598        0.0     2000.0          50.0               JP Lateral
# 14  226599        0.0     1600.0          50.0         Jackson Pratt #1
# 15  226600        0.0     1000.0          30.0         Jackson Pratt #2
# 16  226606        0.0      170.0          10.0  Cerebral Ventricular #1
# 17  226613        0.0     8000.0         100.0             Wound Vac #1
# 18  226616      300.0      300.0         300.0                 Anderson
# 19  227510        0.0     1800.0          10.0              TF Residual
# 20  227701      -20.0     5000.0         100.0             Drainage Bag
# 21  229414        0.0      250.0          40.0            Chest Tube #4

# %%
# Copy the original DataFrame
output4 = output3.copy()

# Define the reference ranges
valid_ranges = {
    226559: (0, 2000),
    226560: (0, 2000),
    226561: (0, 2000),
    226575: (0, 2000),
    226576: (0, 2000),
    226579: (0, 2000),
    226580: (0, 2000),
    226582: (0, 2000),
    226588: (0, 2000),
    226589: (0, 2000),
    226590: (0, 2000),
    226597: (0, 2000),
    226613: (0, 500),
    227510: (0, 500),
    227701: (0, 500),
}

# Separate into rows with itemids in valid_ranges and the rest
to_filter = output4[output4['itemid'].isin(valid_ranges.keys())].copy()
to_keep = output4[~output4['itemid'].isin(valid_ranges.keys())].copy()

# Apply filtering to to_filter
def in_valid_range(row):
    low, high = valid_ranges[row['itemid']]
    return low <= row['value'] <= high

filtered = to_filter[to_filter.apply(in_valid_range, axis=1)]

# Concatenate the filtered and unfiltered subsets
output4 = pd.concat([filtered, to_keep], ignore_index=True)

# %%
output4.head()
# Out:
#    subject_id   stay_id  itemid           charttime  value  label
# 0    10002428  34807493  226559 2156-05-01 07:00:00   35.0  Foley
# 1    10002428  34807493  226559 2156-05-01 08:00:00   35.0  Foley
# 2    10002428  34807493  226559 2156-05-01 09:00:00   35.0  Foley
# 3    10002428  34807493  226559 2156-05-01 10:00:00   35.0  Foley
# 4    10002428  34807493  226559 2156-05-01 11:00:00   35.0  Foley

# %%
output4.shape
# Out:
# (1314752, 6)

# %%
# Check for outliers in the dataframe

summary_stats = output4.groupby('itemid')['value'].agg(
    min_value='min',
    max_value='max',
    median_value='median'
).reset_index()

# Load the d_items CSV
d_items_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/mimic-iv-3.1/icu/d_items.csv'
d_items = pd.read_csv(d_items_path)

# Merge the label column with null_counts using itemid
summary_stats = summary_stats.merge(
    d_items[['itemid', 'label']],  
    on='itemid',
    how='left' 
)

print(summary_stats)
# Out:
#     itemid  min_value  max_value  median_value                    label
# 0   226559        0.0     2000.0          80.0                    Foley
# 1   226560        0.0     2000.0         250.0                     Void
# 2   226561        0.0     1900.0         175.0              Condom Cath
# 3   226572        0.0      700.0         250.0                    Ewald
# 4   226575        0.0     2000.0         100.0              Nasogastric
# 5   226576        0.0     2000.0         100.0             Oral Gastric
# 6   226579        0.0     2000.0         200.0                    Stool
# 7   226580        0.0     2000.0         300.0                Fecal Bag
# 8   226582        0.0     2000.0         150.0          Ostomy (output)
# 9   226588        0.0     2000.0          25.0            Chest Tube #1
# 10  226589        0.0     2000.0          20.0            Chest Tube #2
# 11  226590        0.0     1900.0          20.0             L Pleural #1
# 12  226597        0.0     2000.0          50.0                JP Medial
# 13  226598        0.0     2000.0          50.0               JP Lateral
# 14  226599        0.0     1600.0          50.0         Jackson Pratt #1
# 15  226600        0.0     1000.0          30.0         Jackson Pratt #2
# 16  226606        0.0      170.0          10.0  Cerebral Ventricular #1
# 17  226613        0.0      500.0         100.0             Wound Vac #1
# 18  226616      300.0      300.0         300.0                 Anderson
# 19  227510        0.0      500.0          10.0              TF Residual
# 20  227701        0.0      500.0         100.0             Drainage Bag
# 21  229414        0.0      250.0          40.0            Chest Tube #4

# %%
output5 = output4.copy()

# %%
output5.head()
# Out:
#    subject_id   stay_id  itemid           charttime  value  label
# 0    10002428  34807493  226559 2156-05-01 07:00:00   35.0  Foley
# 1    10002428  34807493  226559 2156-05-01 08:00:00   35.0  Foley
# 2    10002428  34807493  226559 2156-05-01 09:00:00   35.0  Foley
# 3    10002428  34807493  226559 2156-05-01 10:00:00   35.0  Foley
# 4    10002428  34807493  226559 2156-05-01 11:00:00   35.0  Foley

# %%
# Create dataframe which sums 24h output

# Make a copy of the dataframe
output6 = output5.copy()

# Extract the date part for grouping
output6['start_date'] = output6['charttime'].dt.date

# Group by subject_id, stay_id, and start_date
output6 = (
    output6
    .groupby(['subject_id', 'stay_id', 'start_date'])
    .agg(
        charttime=('charttime', 'min'),   # earliest time in the day
        value=('value', 'sum')            # total output in 24h
    )
    .reset_index()
    .rename(columns={'value': '24h_output'})
)

output6.head()
# Out:
#    subject_id   stay_id  start_date           charttime  24h_output
# 0    10002428  33987268  2156-04-12 2156-04-12 18:05:00       355.0
# 1    10002428  33987268  2156-04-13 2156-04-13 00:00:00       560.0
# 2    10002428  33987268  2156-04-14 2156-04-14 00:00:00       437.0
# 3    10002428  33987268  2156-04-15 2156-04-15 00:00:00       507.0
# 4    10002428  33987268  2156-04-16 2156-04-16 00:00:00       730.0

# %%
# Merge input6 and output6 on subject_id, stay_id, and start_date
fb_df = pd.merge(
    input6[['subject_id', 'stay_id', 'start_date', '24h_input']],
    output6[['subject_id', 'stay_id', 'start_date', '24h_output']],
    on=['subject_id', 'stay_id', 'start_date'],
    how='outer'
)

# Compute fluid balance: 24_input - 24_output
fb_df['24h_fb'] = fb_df['24h_input'].fillna(0) - fb_df['24h_output'].fillna(0)

fb_df.head()
# Out:
#    subject_id   stay_id  start_date  24h_input  24h_output  24h_fb
# 0    10002428  33987268  2156-04-12     2900.0       355.0  2545.0
# 1    10002428  33987268  2156-04-13     6440.0       560.0  5880.0
# 2    10002428  33987268  2156-04-14     6150.0       437.0  5713.0
# 3    10002428  33987268  2156-04-15     2040.0       507.0  1533.0
# 4    10002428  33987268  2156-04-16      800.0       730.0    70.0

# %%
# Add new columns with constant values
fb_df['itemid'] = 123456
fb_df['label'] = 'Fluid balance'

# Rename columns
fb_df = fb_df.rename(columns={
    '24h_fb': 'valuenum',
    'start_date': 'charttime'
})

# Drop unnecessary columns
fb_df = fb_df.drop(columns=['24h_input', '24h_output'])

# %%
file_path = '/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/postwean.csv'

# Load the CSV into a DataFrame
outcomes = pd.read_csv(file_path)

outcomes = outcomes[['subject_id', 'stay_id', 'ventilation_time', 'ext_success']]
outcomes = outcomes.drop_duplicates()
fb_df = pd.merge(
    fb_df,
    outcomes[['subject_id', 'ext_success']],
    on=['subject_id'],
    how='inner'  # 
)

# %%
fb_df.head()
# Out:
#    subject_id   stay_id   charttime  valuenum  itemid          label  \
# 0    10002428  33987268  2156-04-12    2545.0  123456  Fluid balance
# 1    10002428  33987268  2156-04-13    5880.0  123456  Fluid balance
# 2    10002428  33987268  2156-04-14    5713.0  123456  Fluid balance
# 3    10002428  33987268  2156-04-15    1533.0  123456  Fluid balance
# 4    10002428  33987268  2156-04-16      70.0  123456  Fluid balance
#
#    ext_success
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
import os

fb_df.to_csv("/Users/mmurali1/Documents/Imperial/MIMICIV_analysis/fb_cleaned_combi.csv", index=False)

# %%
fb_df.shape
# Out:
# (99234, 7)

# %%
fb_df.isnull().sum()
# Out:
# subject_id     0
# stay_id        0
# charttime      0
# valuenum       0
# itemid         0
# label          0
# ext_success    0
# dtype: int64

# %%
# Normalise each value in the 24h_fb column using MinMaxScalar

from sklearn.preprocessing import MinMaxScaler

# Apply MinMaxScaler to 24h_fb
scaler = MinMaxScaler()
fb_df["24hfb_normalized"] = scaler.fit_transform(fb_df[["24h_fb"]])

# %%
fb_df.head(50)
# Out:
#     subject_id   stay_id  start_date  24h_input  24h_output   24h_fb  \
# 0     10002428  33987268  2156-04-12     2900.0       355.0   2545.0
# 1     10002428  33987268  2156-04-13     6440.0       560.0   5880.0
# 2     10002428  33987268  2156-04-14     6150.0       437.0   5713.0
# 3     10002428  33987268  2156-04-15     2040.0       507.0   1533.0
# 4     10002428  33987268  2156-04-16      800.0       730.0     70.0
# 5     10002428  33987268  2156-04-17      400.0       990.0   -590.0
# 6     10002428  34807493  2156-04-30     1000.0         NaN   1000.0
# 7     10002428  34807493  2156-05-01     2420.0      1138.0   1282.0
# 8     10002428  34807493  2156-05-02     1350.0      1260.0     90.0
# 9     10002428  35479615  2156-05-11     3960.0       625.0   3335.0
# 10    10002428  35479615  2156-05-12    13835.0      2230.0  11605.0
# 11    10002428  35479615  2156-05-13     9970.0      1315.0   8655.0
# 12    10002428  35479615  2156-05-14     1939.0      2455.0   -516.0
# 13    10002428  35479615  2156-05-15     2130.0      1620.0    510.0
# 14    10002428  35479615  2156-05-16     1165.0      1030.0    135.0
# 15    10002428  35479615  2156-05-17     1425.0      3720.0  -2295.0
# 16    10002428  35479615  2156-05-18     1820.0       871.0    949.0
# 17    10002428  35479615  2156-05-19     1360.0      2810.0  -1450.0
# 18    10002428  35479615  2156-05-20     1010.0      3080.0  -2070.0
